# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from tqdm import tqdm

# %%
client_id = 'bf5aacb1d35a484cbd7a31afc2b2a821'
client_secret='dca1eb5cca1643c1bf4087a6133a166b'

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, 
                                                                        client_secret=client_secret))

# %%
df = pd.read_csv('spotify_artists.csv')
df
# Out:
#                                            external_urls  followers  \
# 0      https://open.spotify.com/artist/4dpARuHxo51G3z...   57657211
# 1      https://open.spotify.com/artist/66CXWjxzNUsdJx...   98814719
# 2      https://open.spotify.com/artist/13ubrt8QOOCPlj...   14722549
# 3      https://open.spotify.com/artist/06HL4z0CvFAxyc...  118971229
# 4      https://open.spotify.com/artist/7Ln80lUS6He07X...   25991892
# ...                                                  ...        ...
# 20486  https://open.spotify.com/artist/3xx17YXYvPl9PB...      56415
# 20487  https://open.spotify.com/artist/3jvWpZJpokYCoT...      35290
# 20488  https://open.spotify.com/artist/53HxKgLPRmkmUq...         72
# 20489  https://open.spotify.com/artist/0SYlWdOsemdRbG...          0
# 20490  https://open.spotify.com/artist/3YZb2aI52lJJK9...       9343
#
#                                                   genres  \
# 0                    british soul, pop, pop soul, uk pop
# ...

# %%
df = df.dropna(subset=['genres'])
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                            external_urls  followers  \
# 0      https://open.spotify.com/artist/4dpARuHxo51G3z...   57657211
# 1      https://open.spotify.com/artist/66CXWjxzNUsdJx...   98814719
# 2      https://open.spotify.com/artist/13ubrt8QOOCPlj...   14722549
# 3      https://open.spotify.com/artist/06HL4z0CvFAxyc...  118971229
# 4      https://open.spotify.com/artist/7Ln80lUS6He07X...   25991892
# ...                                                  ...        ...
# 14999  https://open.spotify.com/artist/1NrqtKwAa1VXMW...     103432
# 15000  https://open.spotify.com/artist/2x49HGCVPqbRxe...      76890
# 15001  https://open.spotify.com/artist/3xx17YXYvPl9PB...      56415
# 15002  https://open.spotify.com/artist/3jvWpZJpokYCoT...      35290
# 15003  https://open.spotify.com/artist/3YZb2aI52lJJK9...       9343
#
#                                                   genres  \
# 0                    british soul, pop, pop soul, uk pop
# ...

# %%
with open('artist_related_artists.csv', 'a+') as file:
    file.seek(0)
    content = file.readlines()
    for i in tqdm(range(len(content), len(df))):
        artist_related_artists = sp.artist_related_artists(df['id'][i])
        artist_related_artists_str = ', '.join([artist['id'] for artist in artist_related_artists['artists']])
        file.write(f"{df['id'][i]}\t{(artist_related_artists_str)}")
        file.write('\n')
# Out:
# 100%|██████████| 42/42 [00:10<00:00,  3.95it/s]

# %% [markdown]
# #

# %%
df_teste = pd.read_csv('artist_related_artists.csv', header=None, names=['artist_id', 'related_artists_ids'], sep='\t')
df_teste
# Out:
#                     artist_id  \
# 0      4dpARuHxo51G3z768sgnrY
# 1      66CXWjxzNUsdJxJ2JdwvnR
# 2      13ubrt8QOOCPljQ2FL1Kca
# 3      06HL4z0CvFAxyc27GXpf02
# 4      7Ln80lUS6He07XvHI8qqHH
# ...                       ...
# 14999  1NrqtKwAa1VXMWxREFlPPB
# 15000  2x49HGCVPqbRxecj0PZq2R
# 15001  3xx17YXYvPl9PBx6Jzalk4
# 15002  3jvWpZJpokYCoT0QV4OJg0
# 15003  3YZb2aI52lJJK9ektquNK7
#
#                                      related_artists_ids
# 0      5WUlDfRSoLAfcVSX1WnrxN, 2wY79sveU1sp5g7SokKOiI...
# 1      4nDoRrQiYLoBzwC5BhVJzF, 0C8ZW7ezQVs4URX5aX7Kqx...
# 2      5dHt1vcEm9qb8fCyLcB3HL, 2P5sC9cVZDToPxyomzF1UH...
# 3      0C8ZW7ezQVs4URX5aX7Kqx, 1McMsnEElThX1knmY4oliG...
# 4      77SW9BnxLY8rJ0RciFqkHh, 0epOFNiUfyON9EYx7Tpr6V...
# ...                                                  ...
# 14999  3o4RYX3BOwmbGlCcRoXzFe, 7cvWJwt9kcAUzu4bdOBAio...
# 15000  4nd1IvFkUoQinjvYdUmOBI, 3OFUmiZcD0AWtjOYFJVpwM...
# 15001  1Fp2fNrv2udkdpOqFWn8IY, 28C9ybIZUdN7uTb1NBzmBT...
# ...

# %%
retorno = (df_teste['related_artists_ids'][0]).split(', ')
print(len(retorno))

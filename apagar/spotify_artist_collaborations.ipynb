# %% [markdown]
# # **Importando bibliotecas**

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import string
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import time
from util.construction import *
from util.analysis import *
from util.graphics import *

# %% [markdown]
# # **Analisando os dados obtidos**:

# %%
df =  pd.read_csv('data/spotify_artist_collaborations/spotify_artist_collaborations.csv')
df
# Out:
#                                           external_urls  followers  \
# 0     https://open.spotify.com/artist/4dpARuHxo51G3z...   57657211
# 1     https://open.spotify.com/artist/66CXWjxzNUsdJx...   98814719
# 2     https://open.spotify.com/artist/13ubrt8QOOCPlj...   14722549
# 3     https://open.spotify.com/artist/06HL4z0CvFAxyc...  118971229
# 4     https://open.spotify.com/artist/7Ln80lUS6He07X...   25991892
# ...                                                 ...        ...
# 3018  https://open.spotify.com/artist/0pVHBkObr9UNIW...      80561
# 3019  https://open.spotify.com/artist/54kCbQZaZWHnww...    2213913
# 3020  https://open.spotify.com/artist/3qZ2n5keOAat1S...    1799838
# 3021  https://open.spotify.com/artist/2HIP5sNZWkrPgS...      56794
# 3022  https://open.spotify.com/artist/4V6S8Exb51yXRs...     146805
#
#                                                  genres  \
# 0                   british soul, pop, pop soul, uk pop
# 1                                                   pop
# 2                      east coast hip hop, hip hop, rap
# 3                                                   pop
# 4     garage rock, modern rock, permanent wave, rock...
# ...                                                 ...
# 3018                                                NaN
# 3019  french hip hop, pop urbaine, r&b francais, rap...
# 3020    mpb, pagode, partido alto, samba, samba de roda
# 3021                                                NaN
# 3022                                   lo-fi brasileiro
#
#                           id            name  popularity  \
# 0     4dpARuHxo51G3z768sgnrY           Adele          86
# 1     66CXWjxzNUsdJxJ2JdwvnR   Ariana Grande          91
# 2     13ubrt8QOOCPljQ2FL1Kca      A$AP Rocky          84
# 3     06HL4z0CvFAxyc27GXpf02    Taylor Swift         100
# 4     7Ln80lUS6He07XvHI8qqHH  Arctic Monkeys          85
# ...                      ...             ...         ...
# 3018  0pVHBkObr9UNIWpms1e4I0        Zartmann          67
# 3019  54kCbQZaZWHnwwj9VP2hn4            Zola          67
# 3020  3qZ2n5keOAat1SoF6bHwmb  Zeca Pagodinho          65
# 3021  2HIP5sNZWkrPgSBWRk8XpA            SIRA          65
# 3022  4V6S8Exb51yXRs6oiJYIgE         SonoTWS          66
#
#                                         uri  \
# 0     spotify:artist:4dpARuHxo51G3z768sgnrY
# 1     spotify:artist:66CXWjxzNUsdJxJ2JdwvnR
# 2     spotify:artist:13ubrt8QOOCPljQ2FL1Kca
# 3     spotify:artist:06HL4z0CvFAxyc27GXpf02
# 4     spotify:artist:7Ln80lUS6He07XvHI8qqHH
# ...                                     ...
# 3018  spotify:artist:0pVHBkObr9UNIWpms1e4I0
# 3019  spotify:artist:54kCbQZaZWHnwwj9VP2hn4
# 3020  spotify:artist:3qZ2n5keOAat1SoF6bHwmb
# 3021  spotify:artist:2HIP5sNZWkrPgSBWRk8XpA
# 3022  spotify:artist:4V6S8Exb51yXRs6oiJYIgE
#
#                                      collaborations_ids  \
# 0                                                   NaN
# 1     2wIVse2owClT7go1WT98tk, 0hCNtLu0JehylgoiP8L4Gh...
# 2     0k7Xl1pqI3tu8sSEjo5oEg, 2P5sC9cVZDToPxyomzF1UH...
# 3     0u2FHSq3ln94y5Q57xazwf, 4YLtscXsxbVgi031ovDDdh...
# 4                                                   NaN
# ...                                                 ...
# 3018  13bDjug9N0pyv3ZUINjkDV, 6CP5wWvO8oIxedESJNCN4H...
# 3019  3vUMXQ9kPnZAQkMkZZ7Hfh, 2kXKa3aAFngGz2P4GjG5w2...
# 3020  7HGNYPmbDrMkylWqeFCOIQ, 7yQrcdkLdBAkV7yY9fF2Hw...
# 3021                                                NaN
# 3022                             1iVZ4G8loVE1bb5EWuOvMM
#
#                                          collaborations
# 0                                                   NaN
# 1     'Missy Elliott', 'Nicki Minaj', 'Jessie J', 'C...
# 2     'Paul Wall', 'Main Attrakionz', 'Joey Bada$$',...
# 3     'Hayley Williams', 'Keith Urban', 'Chris Stapl...
# 4                                                   NaN
# ...                                                 ...
# 3018  'Aaron', 'Bausa', 'Ski Aggu', 'Dauner', 'Kasi'...
# 3019  'Key Largo', 'Tiakola', 'Noname', 'SCH', 'Dams...
# 3020  'Arlindo Cruz', 'Caetano Veloso', 'Pepeu Gomes...
# 3021                                                NaN
# 3022  'Zorack', 'Shanique Marie', 'pumapjl', '.I of ...
#
# [3023 rows x 9 columns]

# %%
network = createNetowrk(df, 'collaborations_ids')
toEdgesList(network, 'spotify_artist_collaborations')

# %%
printInformations(network)
# Out:
# Quantidade de vértices: 3023
# Quantidade de arestas: 13993
# Quantidade de componentes: 782
# Menor grau da rede: 0
# Maior grau da rede: 131
# Grau médio da rede: 9.257691035395302
# Densidade da rede: 0.0030634318449355735
# Distância média: 4.27614614144718
# Coeficiente de clustering médio: 0.25112517375709126 (apenas 64.01% da rede foi considerada no cálculo, que que possuem grau maior do que um)

# %%
frequencies_of_degrees, probability_of_degrees, accumulated_probability_of_degress = degreeDistribution(network)

# %%
createGraphic(data = frequencies_of_degrees, xLabel = 'Grau (K)', yLabel = 'Frequência', title = 'Frequência dos Graus', limit = 5, lines = False, name_network = 'spotify_related_artists')

# %%
createGraphic(data = probability_of_degrees, xLabel = 'Grau (K)', yLabel = 'P(k)', title = 'Probabilidade dos Graus', limit = 0.01, lines = False,  name_network = 'spotify_related_artists')

# %%
createGraphic(data = accumulated_probability_of_degress, xLabel = 'Grau (k)', yLabel = 'P(>=K)', title = 'Função de Distribuição Cumulativa Complementar', limit = 0.05, lines = True,  name_network = 'spotify_related_artists')

# %%
degree_centrality, eigenvector_centrality, closeness_centrality, betweenness_centrality = calculateCentralities(network)

# %%
analysis_centrality = createGraphicCentrality(data = degree_centrality, title = 'Centralidade por Grau', name_network = 'spotify_related_artists')
printInformationAnalysisCentrality(analysis_centrality)
# Out:
# Informações gerais sobre os resultados encontrados:
# 	Quantidade de valores diferentes para a centralidade em estudo: 93.
# 	O menor valor é 0.0 e sua frequência é 734.
# 	O maior valor é 0.04334877564526803 e sua frequência é 1.

# %%
createRankingCentrality(df=df, centrality = degree_centrality, network = network, title = 'Centralidade por grau', name_network = 'spotify_related_artists')

# %%
analysis_centrality = createGraphicCentrality(data = eigenvector_centrality, title = 'Centralidade por Autovetor', name_network = 'spotify_related_artists')
printInformationAnalysisCentrality(analysis_centrality)
# Out:
# Informações gerais sobre os resultados encontrados:
# 	Quantidade de valores diferentes para a centralidade em estudo: 2132.
# 	O menor valor é 3.6538302798999257e-40 e sua frequência é 734.
# 	O maior valor é 0.1816914340804239 e sua frequência é 1.

# %%
centrality_ranking = sorted(eigenvector_centrality, reverse = True)
createRankingCentrality(df=df, centrality = eigenvector_centrality, network = network, title = 'Centralidade por Autovetor', name_network = 'spotify_related_artists')

# %%
analysis_centrality = createGraphicCentrality(data = closeness_centrality, title = 'Centralidade por Closeness', name_network = 'spotify_related_artists')
printInformationAnalysisCentrality(analysis_centrality)
# Out:
# Informações gerais sobre os resultados encontrados:
# 	Quantidade de valores diferentes para a centralidade em estudo: 1741.
# 	O menor valor é 0.0 e sua frequência é 734.
# 	O maior valor é 0.2535226384876215 e sua frequência é 1.

# %%
centrality_ranking = sorted(closeness_centrality, reverse = True)
createRankingCentrality(df=df, centrality = closeness_centrality, network = network, title = 'Centralidade por Closeness', name_network = 'spotify_related_artists')

# %%
analysis_centrality = createGraphicCentrality(data = betweenness_centrality, title = 'Centralidade por Betweenness', name_network = 'spotify_related_artists')
printInformationAnalysisCentrality(analysis_centrality)
# Out:
# Informações gerais sobre os resultados encontrados:
# 	Quantidade de valores diferentes para a centralidade em estudo: 1800.
# 	O menor valor é 0.0 e sua frequência é 1178.
# 	O maior valor é 0.03212458690793592 e sua frequência é 1.

# %%
centrality_ranking = sorted(betweenness_centrality, reverse = True)
createRankingCentrality(df=df, centrality = betweenness_centrality, network = network, title = 'Centralidade por Betweenness', name_network = 'spotify_related_artists')
